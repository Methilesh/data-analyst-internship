# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data=pd.read_csv(r"/content/Data-cleaning-for-beginners-using-pandas.csv")

# %%
copy_data = data.copy()

# %%
data
# Out:
#     Index   Age      Salary  Rating       Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4       India,In         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2       2   NaN   $77k-$89k    -1.0    New York,Ny           -1         -1
# 3       3  64.0   $44k-$99k     4.4       India In         1988         -1
# 4       4  25.0   $44k-$99k     6.4  Australia Aus         2002         -1
# 5       5  44.0   $77k-$89k     1.4       India,In         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0    New York,Ny           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  Australia Aus           -1         -1
# 8       8  35.0   $44k-$99k     5.4    New York,Ny           -1         -1
# 9       9  22.0   $44k-$99k     7.7       India,In           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4       India,In         2008       TRUE
# ...

# %%
data.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2   NaN  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data.tail()
# Out:
#     Index   Age     Salary  Rating       Location  Established Easy Apply
# 24     24  13.0  $44k-$99k    -1.0    New York,Ny         1987         -1
# 25     25  55.0  $44k-$99k     0.0  Australia Aus         1980       TRUE
# 26     26   NaN  $55k-$66k     NaN       India,In         1934       TRUE
# 27     27  52.0  $44k-$99k     5.4       India,In         1935         -1
# 28     28   NaN  $39k-$88k     3.4  Australia Aus         1932         -1

# %%
data.shape
# Out:
# (29, 7)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Index        29 non-null     int64
#  1   Age          22 non-null     float64
#  2   Salary       29 non-null     object
#  3   Rating       28 non-null     float64
#  4   Location     29 non-null     object
#  5   Established  29 non-null     int64
#  6   Easy Apply   29 non-null     object
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.7+ KB

# %%
data.isnull().sum()
# Out:
# Index          0
# Age            7
# Salary         0
# Rating         1
# Location       0
# Established    0
# Easy Apply     0
# dtype: int64

# %%
data.columns
# Out:
# Index(['Index', 'Age', 'Salary', 'Rating', 'Location', 'Established',
#        'Easy Apply'],
#       dtype='object')

# %%
sample = data.columns.str.lower().str.replace(" ","_")

# %%
text = '$40k-$100k'
text.replace('$',"")
# Out:
# '40k-100k'

# %%
sample
# Out:
# Index(['index', 'age', 'salary', 'rating', 'location', 'established',
#        'easy_apply'],
#       dtype='object')

# %%
avg_age = data['Age'].mean()
avg_age
# Out:
# 39.04545454545455

# %%
data['Age'] = data.Age.fillna(avg_age)
data['Age'] = data.Age.round(decimals=1)

# %%
data.head()
# Out:
#    Index   Age     Salary  Rating       Location  Established Easy Apply
# 0      0  44.0  $44k-$99k     5.4       India,In         1999       TRUE
# 1      1  66.0  $55k-$66k     3.5    New York,Ny         2002       TRUE
# 2      2  39.0  $77k-$89k    -1.0    New York,Ny           -1         -1
# 3      3  64.0  $44k-$99k     4.4       India In         1988         -1
# 4      4  25.0  $44k-$99k     6.4  Australia Aus         2002         -1

# %%
data['Age']
# Out:
# 0     44.0
# 1     66.0
# 2     39.0
# 3     64.0
# 4     25.0
# 5     44.0
# 6     21.0
# 7     44.0
# 8     35.0
# 9     22.0
# 10    55.0
# 11    44.0
# 12    39.0
# 13    25.0
# 14    66.0
# 15    44.0
# 16    19.0
# 17    39.0
# 18    35.0
# 19    32.0
# 20    39.0
# 21    35.0
# 22    19.0
# 23    39.0
# 24    13.0
# 25    55.0
# 26    39.0
# 27    52.0
# 28    39.0
# Name: Age, dtype: float64

# %%
data
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      india         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   new york         2002       TRUE
# 2       2  39.0   $77k-$89k    -1.0   new york           -1         -1
# 3       3  64.0   $44k-$99k     4.4      india         1988         -1
# 4       4  25.0   $44k-$99k     6.4  australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      india         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   new york           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  australia           -1         -1
# 8       8  35.0   $44k-$99k     5.4   new york           -1         -1
# 9       9  22.0   $44k-$99k     7.7      india           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4      india         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      india         2009         -1
# ...

# %%
data['Location'].value_counts()
# Out:
# New York,Ny      12
# India,In          9
# Australia Aus     7
# India In          1
# Name: Location, dtype: int64

# %%
data['Location'] = data['Location'].replace({'New York,Ny':'New York', 'India,In':'India','India In':'India', 'Australia Aus':'Australia'})

# %%
data['Location'] = data['Location'].str.replace(r'\sIn$', '')
# Out:
# <ipython-input-27-3f59ccad5d6c>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   data['Location'] = data['Location'].str.replace(r'\sIn$', '')

# %%
l = ['India','In']
l[1]
# Out:
# 'In'

# %%
data['Location'].str.split(",",expand=True)[0]
# Out:
# 0         India
# 1      New York
# 2      New York
# 3         India
# 4     Australia
# 5         India
# 6      New York
# 7     Australia
# 8      New York
# 9         India
# 10        India
# 11        India
# 12        India
# 13    Australia
# 14    Australia
# 15    Australia
# 16        India
# 17     New York
# 18     New York
# 19     New York
# 20     New York
# 21     New York
# 22     New York
# 23     New York
# 24     New York
# 25    Australia
# 26        India
# 27        India
# 28    Australia
# Name: 0, dtype: object

# %%
data["Location"] = data["Location"].str.lower().str.replace(",", " " ).str.rstrip("in")

# %%
data['Location'].str.lower().str.replace(",","").str.rstrip("in")
# Out:
# 0         india
# 1      new york
# 2      new york
# 3         india
# 4     australia
# 5         india
# 6      new york
# 7     australia
# 8      new york
# 9         india
# 10        india
# 11        india
# 12        india
# 13    australia
# 14    australia
# 15    australia
# 16        india
# 17     new york
# 18     new york
# 19     new york
# 20     new york
# 21     new york
# 22     new york
# 23     new york
# 24     new york
# 25    australia
# 26        india
# 27        india
# 28    australia
# Name: Location, dtype: object

# %%
data['Location'].astype
# Out:
# <bound method NDFrame.astype of 0         india
# 1      new york
# 2      new york
# 3         india
# 4     australia
# 5         india
# 6      new york
# 7     australia
# 8      new york
# 9         india
# 10        india
# 11        india
# 12        india
# 13    australia
# 14    australia
# 15    australia
# 16        india
# 17     new york
# 18     new york
# 19     new york
# 20     new york
# 21     new york
# 22     new york
# 23     new york
# 24     new york
# 25    australia
# 26        india
# 27        india
# 28    australia
# Name: Location, dtype: object>

# %%
data
# Out:
#     Index   Age      Salary  Rating   Location  Established Easy Apply
# 0       0  44.0   $44k-$99k     5.4      india         1999       TRUE
# 1       1  66.0   $55k-$66k     3.5   new york         2002       TRUE
# 2       2  39.0   $77k-$89k    -1.0   new york           -1         -1
# 3       3  64.0   $44k-$99k     4.4      india         1988         -1
# 4       4  25.0   $44k-$99k     6.4  australia         2002         -1
# 5       5  44.0   $77k-$89k     1.4      india         1999       TRUE
# 6       6  21.0   $44k-$99k     0.0   new york           -1         -1
# 7       7  44.0   $44k-$99k    -1.0  australia           -1         -1
# 8       8  35.0   $44k-$99k     5.4   new york           -1         -1
# 9       9  22.0   $44k-$99k     7.7      india           -1       TRUE
# 10     10  55.0   $10k-$49k     5.4      india         2008       TRUE
# 11     11  44.0   $10k-$49k     6.7      india         2009         -1
# ...

# %%
data['Salary']=data.Salary.str.replace("$"," ")
# Out:
# <ipython-input-46-721aca357147>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Salary']=data.Salary.str.replace("$"," ")

# %%
data['Salary']=data.Salary.str.replace("k", "000")

# %%
data[['Min_Salary', 'Max Salary']] = data['Salary'].str.split('-', expand=True)

# %%
data = data.drop(columns=['Salary'])

# %%
data
# Out:
#     Index   Age  Rating   Location  Established Easy Apply Min_Salary  \
# 0       0  44.0     5.4      india         1999       TRUE      44000
# 1       1  66.0     3.5   new york         2002       TRUE      55000
# 2       2  39.0    -1.0   new york           -1         -1      77000
# 3       3  64.0     4.4      india         1988         -1      44000
# 4       4  25.0     6.4  australia         2002         -1      44000
# 5       5  44.0     1.4      india         1999       TRUE      77000
# 6       6  21.0     0.0   new york           -1         -1      44000
# 7       7  44.0    -1.0  australia           -1         -1      44000
# 8       8  35.0     5.4   new york           -1         -1      44000
# 9       9  22.0     7.7      india           -1       TRUE      44000
# 10     10  55.0     5.4      india         2008       TRUE      10000
# 11     11  44.0     6.7      india         2009         -1      10000
# ...
